# %% [markdown]
# #### Importing relevant libraries

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in d:\wpsystem\s-1-5-21-4107825695-3292302581-3182530918-1001\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (3.1.0)
# Requirement already satisfied: et-xmlfile in d:\wpsystem\s-1-5-21-4107825695-3292302581-3182530918-1001\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# #### Reading the dataset and showing its content

# %%
dataset = pd.read_excel("Pistachio_28_Features_Dataset.xlsx")

# %%
dataset
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0    422163  2378.9080    837.8484    645.6693        0.6373  733.1539
# 1    338136  2085.1440    723.8198    595.2073        0.5690  656.1464
# 2    526843  2647.3940    940.7379    715.3638        0.6494  819.0222
# 3    416063  2351.2100    827.9804    645.2988        0.6266  727.8378
# 4    347562  2160.3540    763.9877    582.8359        0.6465  665.2291
# ..      ...        ...         ...         ...           ...       ...
# 893  255403  1925.3650    691.8453    477.1796        0.7241  570.2536
# 894  365924  2664.8230    855.4633    551.5447        0.7644  682.5752
# 895  254330  1926.7360    747.4943    435.6219        0.8126  569.0545
# 896  238955  1906.2679    716.6485    441.8297        0.7873  551.5859
# 897  343792  2289.2720    823.8438    534.7757        0.7607  661.6113
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# 0      0.9947       424428  0.7831        1.2976  ...      3.2370      2.9574
# 1      0.9974       339014  0.7795        1.2161  ...      2.6228      2.6350
# 2      0.9962       528876  0.7657        1.3150  ...      3.7516      3.8611
# 3      0.9948       418255  0.7759        1.2831  ...      5.0401      8.6136
# 4      0.9908       350797  0.7569        1.3108  ...      2.7016      2.9761
# ..        ...          ...     ...           ...  ...         ...         ...
# 893    0.9785       261028  0.7269        1.4499  ...      2.2423      2.3704
# 894    0.9466       386566  0.6695        1.5510  ...      3.4109      3.5805
# 895    0.9925       256255  0.7240        1.7159  ...      2.2759      2.5090
# 896    0.9604       248795  0.6954        1.6220  ...      2.6769      2.6874
# 897    0.9781       351472  0.6941        1.5405  ...      2.5138      3.0369
#
#      KurtosisRB    EntropyRR    EntropyRG    EntropyRB  ALLdaub4RR  \
# 0        4.2287 -59191263232 -50714214400 -39922372608     58.7255
# 1        3.1704 -34233065472 -37462601728 -31477794816     50.0259
# 2        4.7192 -93948354560 -74738221056 -60311207936     65.4772
# 3        8.2618 -32074307584 -32060925952 -29575010304     43.3900
# 4        4.4146 -39980974080 -35980042240 -25593278464     52.7743
# ..          ...          ...          ...          ...         ...
# 893      2.7202 -25296416768 -19168882688 -18473392128     49.0869
# 894      3.9910 -31605219328 -21945366528 -19277905920     46.8086
# 895      2.6951 -22242772992 -19594921984 -17592152064     44.1325
# 896      2.7991 -26048595968 -21299822592 -19809978368     51.2267
# 897      3.0865 -31983476736 -20482514944 -21219354624     47.3454
#
#      ALLdaub4RG  ALLdaub4RB  Class
# 0       54.9554     47.8400  BERHI
# 1       52.8168     47.8315  BERHI
# 2       59.2860     51.9378  BERHI
# 3       44.1259     41.1882  BERHI
# 4       50.9080     42.6666  BERHI
# ..          ...         ...    ...
# 893     43.0422     42.4153  SOGAY
# 894     39.1046     36.5502  SOGAY
# 895     40.7986     40.9769  SOGAY
# 896     45.7162     45.6260  SOGAY
# 897     38.6966     39.6738  SOGAY
#
# [898 rows x 35 columns]

# %% [markdown]
# ### Separating the inputs and the targets

# %%
x = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# %%
x = x.values
y = y.values

# %% [markdown]
# ### Deleting an outlier

# %%
#x = np.delete(x, 615, axis = 0)
#y = np.delete(y, 615, axis = 0)

# %%
x
# Out:
# array([[4.2216300e+05, 2.3789080e+03, 8.3784840e+02, ..., 5.8725500e+01,
#         5.4955400e+01, 4.7840000e+01],
#        [3.3813600e+05, 2.0851440e+03, 7.2381980e+02, ..., 5.0025900e+01,
#         5.2816800e+01, 4.7831500e+01],
#        [5.2684300e+05, 2.6473940e+03, 9.4073790e+02, ..., 6.5477200e+01,
#         5.9286000e+01, 5.1937800e+01],
#        ...,
#        [2.5433000e+05, 1.9267360e+03, 7.4749430e+02, ..., 4.4132500e+01,
#         4.0798600e+01, 4.0976900e+01],
#        [2.3895500e+05, 1.9062679e+03, 7.1664850e+02, ..., 5.1226700e+01,
#         4.5716200e+01, 4.5626000e+01],
#        [3.4379200e+05, 2.2892720e+03, 8.2384380e+02, ..., 4.7345400e+01,
#         3.8696600e+01, 3.9673800e+01]])

# %% [markdown]
# ### Plotting the first set of features

# %%
plt.figure(figsize = (12, 8))
plt.scatter(range(len(x[:, 0])), x[:, 1], c = range(len(x)), cmap = 'magma')

# %% [markdown]
# #### Creating two methods: one for normalization and the other for feature selection

# %%
def normalize(x):
    scaler = MinMaxScaler()
    return scaler.fit_transform(x)

# %%
def select_important_features(x, y, n):
    selector = SelectKBest(
        chi2,
        k = n
    )
    selection = selector.fit_transform(x, y)
    return selection

# %% [markdown]
# #### Normalizing the inputs

# %%
x = normalize(x)

# %% [markdown]
# #### Selecting top features

# %%
important_features = select_important_features(x, y, 30)

# %% [markdown]
# #### Dynamically setting the input size of the neual net based on the feature size

# %%
input_size = important_features.shape[1]

# %% [markdown]
# #### OneHotEncod'ing the target values

# %%
encoder = OneHotEncoder()
encoder.fit(y.reshape(len(y), 1))
y = encoder.transform(y.reshape(len(y), 1))

# %% [markdown]
# #### Splitting the data

# %%
x_train, x_test, y_train, y_test = train_test_split(important_features, y.toarray(), test_size = 0.2, random_state = 10)

# %% [markdown]
# ### Initializing the model

# %%
model = keras.Sequential()
model.add(Input(shape = input_size))
model.add(Dense(100, activation = 'relu'))
model.add(Dense(100, activation = 'relu'))
model.add(Dense(50, activation = 'relu'))
model.add(Dense(7, activation = 'sigmoid'))

# %% [markdown]
# #### Compiling the model with adam optimizer

# %%
model.compile(optimizer = keras.optimizers.Adam(learning_rate = 0.0001), loss = 'binary_crossentropy', metrics = 'accuracy')

# %% [markdown]
# ### fitting the model to the dataset with a limit of iterations that stops before turning into overfitting

# %%
history = model.fit(x_train, y_train, epochs = 100, validation_data = (x_test, y_test))
# Out:
# Epoch 1/100
# 23/23 [==============================] - 1s 9ms/step - loss: 0.6489 - accuracy: 0.8468 - val_loss: 0.5769 - val_accuracy: 0.7778
# Epoch 2/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4584 - accuracy: 0.7368 - val_loss: 0.4323 - val_accuracy: 0.7611
# Epoch 3/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3484 - accuracy: 0.7270 - val_loss: 0.3335 - val_accuracy: 0.7667
# Epoch 4/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2711 - accuracy: 0.7409 - val_loss: 0.2601 - val_accuracy: 0.7778
# Epoch 5/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2190 - accuracy: 0.7604 - val_loss: 0.2120 - val_accuracy: 0.8000
# Epoch 6/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1896 - accuracy: 0.7716 - val_loss: 0.1853 - val_accuracy: 0.8167
# Epoch 7/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1751 - accuracy: 0.7841 - val_loss: 0.1723 - val_accuracy: 0.8278
# Epoch 8/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1684 - accuracy: 0.7911 - val_loss: 0.1649 - val_accuracy: 0.8333
# Epoch 9/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1646 - accuracy: 0.7953 - val_loss: 0.1599 - val_accuracy: 0.8333
# Epoch 10/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1622 - accuracy: 0.8036 - val_loss: 0.1568 - val_accuracy: 0.8444
# Epoch 11/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1594 - accuracy: 0.8050 - val_loss: 0.1541 - val_accuracy: 0.8278
# Epoch 12/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1572 - accuracy: 0.8078 - val_loss: 0.1521 - val_accuracy: 0.8389
# Epoch 13/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1554 - accuracy: 0.8162 - val_loss: 0.1504 - val_accuracy: 0.8500
# Epoch 14/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1534 - accuracy: 0.8148 - val_loss: 0.1478 - val_accuracy: 0.8389
# Epoch 15/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1520 - accuracy: 0.8245 - val_loss: 0.1471 - val_accuracy: 0.8389
# Epoch 16/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1504 - accuracy: 0.8217 - val_loss: 0.1452 - val_accuracy: 0.8389
# Epoch 17/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1493 - accuracy: 0.8189 - val_loss: 0.1432 - val_accuracy: 0.8444
# Epoch 18/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1480 - accuracy: 0.8231 - val_loss: 0.1424 - val_accuracy: 0.8500
# Epoch 19/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1468 - accuracy: 0.8329 - val_loss: 0.1415 - val_accuracy: 0.8556
# Epoch 20/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1455 - accuracy: 0.8329 - val_loss: 0.1399 - val_accuracy: 0.8444
# Epoch 21/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1446 - accuracy: 0.8357 - val_loss: 0.1390 - val_accuracy: 0.8389
# Epoch 22/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1435 - accuracy: 0.8384 - val_loss: 0.1377 - val_accuracy: 0.8556
# Epoch 23/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1426 - accuracy: 0.8315 - val_loss: 0.1367 - val_accuracy: 0.8444
# Epoch 24/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1418 - accuracy: 0.8426 - val_loss: 0.1361 - val_accuracy: 0.8500
# Epoch 25/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1407 - accuracy: 0.8398 - val_loss: 0.1349 - val_accuracy: 0.8556
# Epoch 26/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1397 - accuracy: 0.8454 - val_loss: 0.1343 - val_accuracy: 0.8556
# Epoch 27/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1390 - accuracy: 0.8496 - val_loss: 0.1336 - val_accuracy: 0.8611
# Epoch 28/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1384 - accuracy: 0.8482 - val_loss: 0.1327 - val_accuracy: 0.8556
# Epoch 29/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1375 - accuracy: 0.8468 - val_loss: 0.1322 - val_accuracy: 0.8556
# Epoch 30/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1368 - accuracy: 0.8496 - val_loss: 0.1312 - val_accuracy: 0.8556
# Epoch 31/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1360 - accuracy: 0.8468 - val_loss: 0.1301 - val_accuracy: 0.8500
# Epoch 32/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1354 - accuracy: 0.8496 - val_loss: 0.1299 - val_accuracy: 0.8611
# Epoch 33/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1346 - accuracy: 0.8593 - val_loss: 0.1296 - val_accuracy: 0.8556
# Epoch 34/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1337 - accuracy: 0.8524 - val_loss: 0.1283 - val_accuracy: 0.8611
# Epoch 35/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1331 - accuracy: 0.8524 - val_loss: 0.1280 - val_accuracy: 0.8611
# Epoch 36/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1322 - accuracy: 0.8538 - val_loss: 0.1271 - val_accuracy: 0.8556
# Epoch 37/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1315 - accuracy: 0.8510 - val_loss: 0.1261 - val_accuracy: 0.8611
# Epoch 38/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1310 - accuracy: 0.8524 - val_loss: 0.1253 - val_accuracy: 0.8556
# Epoch 39/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.8565 - val_loss: 0.1251 - val_accuracy: 0.8611
# Epoch 40/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1294 - accuracy: 0.8524 - val_loss: 0.1242 - val_accuracy: 0.8611
# Epoch 41/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1288 - accuracy: 0.8565 - val_loss: 0.1237 - val_accuracy: 0.8667
# Epoch 42/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1284 - accuracy: 0.8552 - val_loss: 0.1232 - val_accuracy: 0.8611
# Epoch 43/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1276 - accuracy: 0.8538 - val_loss: 0.1220 - val_accuracy: 0.8611
# Epoch 44/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1267 - accuracy: 0.8538 - val_loss: 0.1218 - val_accuracy: 0.8611
# Epoch 45/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1261 - accuracy: 0.8510 - val_loss: 0.1215 - val_accuracy: 0.8611
# Epoch 46/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1255 - accuracy: 0.8593 - val_loss: 0.1204 - val_accuracy: 0.8667
# Epoch 47/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1247 - accuracy: 0.8538 - val_loss: 0.1205 - val_accuracy: 0.8667
# Epoch 48/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1241 - accuracy: 0.8565 - val_loss: 0.1188 - val_accuracy: 0.8667
# Epoch 49/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8565 - val_loss: 0.1190 - val_accuracy: 0.8667
# Epoch 50/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8565 - val_loss: 0.1181 - val_accuracy: 0.8667
# Epoch 51/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1222 - accuracy: 0.8593 - val_loss: 0.1176 - val_accuracy: 0.8611
# Epoch 52/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1218 - accuracy: 0.8593 - val_loss: 0.1173 - val_accuracy: 0.8722
# Epoch 53/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1207 - accuracy: 0.8635 - val_loss: 0.1165 - val_accuracy: 0.8667
# Epoch 54/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1205 - accuracy: 0.8552 - val_loss: 0.1166 - val_accuracy: 0.8611
# Epoch 55/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1197 - accuracy: 0.8621 - val_loss: 0.1157 - val_accuracy: 0.8611
# Epoch 56/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1193 - accuracy: 0.8593 - val_loss: 0.1152 - val_accuracy: 0.8667
# Epoch 57/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1187 - accuracy: 0.8635 - val_loss: 0.1145 - val_accuracy: 0.8667
# Epoch 58/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1182 - accuracy: 0.8552 - val_loss: 0.1141 - val_accuracy: 0.8667
# Epoch 59/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1174 - accuracy: 0.8621 - val_loss: 0.1139 - val_accuracy: 0.8611
# Epoch 60/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1172 - accuracy: 0.8691 - val_loss: 0.1133 - val_accuracy: 0.8722
# Epoch 61/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1166 - accuracy: 0.8565 - val_loss: 0.1122 - val_accuracy: 0.8667
# Epoch 62/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1159 - accuracy: 0.8663 - val_loss: 0.1124 - val_accuracy: 0.8667
# Epoch 63/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1153 - accuracy: 0.8621 - val_loss: 0.1121 - val_accuracy: 0.8611
# Epoch 64/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1146 - accuracy: 0.8649 - val_loss: 0.1110 - val_accuracy: 0.8667
# Epoch 65/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1142 - accuracy: 0.8705 - val_loss: 0.1109 - val_accuracy: 0.8667
# Epoch 66/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1140 - accuracy: 0.8677 - val_loss: 0.1104 - val_accuracy: 0.8667
# Epoch 67/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1131 - accuracy: 0.8691 - val_loss: 0.1105 - val_accuracy: 0.8667
# Epoch 68/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1127 - accuracy: 0.8621 - val_loss: 0.1096 - val_accuracy: 0.8667
# Epoch 69/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1122 - accuracy: 0.8663 - val_loss: 0.1090 - val_accuracy: 0.8667
# Epoch 70/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1117 - accuracy: 0.8649 - val_loss: 0.1088 - val_accuracy: 0.8667
# Epoch 71/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1113 - accuracy: 0.8663 - val_loss: 0.1084 - val_accuracy: 0.8722
# Epoch 72/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1108 - accuracy: 0.8705 - val_loss: 0.1078 - val_accuracy: 0.8667
# Epoch 73/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1104 - accuracy: 0.8677 - val_loss: 0.1070 - val_accuracy: 0.8722
# Epoch 74/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1097 - accuracy: 0.8677 - val_loss: 0.1075 - val_accuracy: 0.8667
# Epoch 75/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1092 - accuracy: 0.8635 - val_loss: 0.1066 - val_accuracy: 0.8667
# Epoch 76/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1084 - accuracy: 0.8663 - val_loss: 0.1062 - val_accuracy: 0.8778
# Epoch 77/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.8677 - val_loss: 0.1060 - val_accuracy: 0.8667
# Epoch 78/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1078 - accuracy: 0.8705 - val_loss: 0.1054 - val_accuracy: 0.8722
# Epoch 79/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1073 - accuracy: 0.8705 - val_loss: 0.1052 - val_accuracy: 0.8722
# Epoch 80/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1069 - accuracy: 0.8607 - val_loss: 0.1048 - val_accuracy: 0.8722
# Epoch 81/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1064 - accuracy: 0.8677 - val_loss: 0.1046 - val_accuracy: 0.8722
# Epoch 82/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1073 - accuracy: 0.8691 - val_loss: 0.1039 - val_accuracy: 0.8722
# Epoch 83/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1060 - accuracy: 0.8719 - val_loss: 0.1042 - val_accuracy: 0.8722
# Epoch 84/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1052 - accuracy: 0.8733 - val_loss: 0.1034 - val_accuracy: 0.8833
# Epoch 85/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1052 - accuracy: 0.8677 - val_loss: 0.1035 - val_accuracy: 0.8778
# Epoch 86/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1050 - accuracy: 0.8677 - val_loss: 0.1025 - val_accuracy: 0.8722
# Epoch 87/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1042 - accuracy: 0.8705 - val_loss: 0.1024 - val_accuracy: 0.8778
# Epoch 88/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1038 - accuracy: 0.8760 - val_loss: 0.1021 - val_accuracy: 0.8778
# Epoch 89/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1033 - accuracy: 0.8705 - val_loss: 0.1020 - val_accuracy: 0.8722
# Epoch 90/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1029 - accuracy: 0.8733 - val_loss: 0.1024 - val_accuracy: 0.8833
# Epoch 91/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1030 - accuracy: 0.8733 - val_loss: 0.1016 - val_accuracy: 0.8833
# Epoch 92/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1018 - accuracy: 0.8774 - val_loss: 0.1010 - val_accuracy: 0.8833
# Epoch 93/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1016 - accuracy: 0.8760 - val_loss: 0.1004 - val_accuracy: 0.8778
# Epoch 94/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1013 - accuracy: 0.8733 - val_loss: 0.1004 - val_accuracy: 0.8833
# Epoch 95/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1010 - accuracy: 0.8733 - val_loss: 0.1010 - val_accuracy: 0.8833
# Epoch 96/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1004 - accuracy: 0.8719 - val_loss: 0.1001 - val_accuracy: 0.8833
# Epoch 97/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0999 - accuracy: 0.8760 - val_loss: 0.1003 - val_accuracy: 0.8944
# Epoch 98/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1003 - accuracy: 0.8774 - val_loss: 0.0994 - val_accuracy: 0.8833
# Epoch 99/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0995 - accuracy: 0.8816 - val_loss: 0.0993 - val_accuracy: 0.9000
# Epoch 100/100
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0995 - accuracy: 0.8760 - val_loss: 0.0991 - val_accuracy: 0.8889

# %% [markdown]
# #### Extracting the fitting history data

# %%
loss = history.history['loss']
accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']

# %% [markdown]
# #### Plotting the accuracy and accuracy validation score along with the loss and loss validation

# %%
plt.rcParams.update({'font.size': 18})
plt.figure(figsize=(5, 5))
plt.plot(range(len(loss)), loss)
plt.plot(range(len(accuracy)), accuracy)
plt.plot(range(len(val_loss)), val_loss)
plt.plot(range(len(val_accuracy)), val_accuracy)
plt.legend(['loss', 'accuracy', 'val_loss', 'val_accuracy'], fontsize = 12)
