# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2 as cv2

# %%
img = cv2.imread('imgpuppy.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (600, 800, 3)

# %%
#plt.imshow(img) #matplotlib and opencv expects different ordering of color channels.
""" OPENCV reads it as BGR and Matplotlib reads it as RGB image so while displaying from matplotlib it displays as if its an RGB image"""
fixed_img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)
plt.imshow(fixed_img)

# %%
img_gray = cv2.imread('imgpuppy.jpg' , cv2.IMREAD_GRAYSCALE)
img_gray.shape
# Out:
# (600, 800)

# %%
img_gray.max()
img_gray.min()
# Out:
# 0

# %%
plt.imshow(img_gray)
